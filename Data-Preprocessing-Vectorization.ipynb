# %% [markdown]
# # 1. استكشاف البيانات الشعرية
#
# # Exploring Arabic Poem Comprehensive Dataset

# %%
import pandas as pd
import numpy as np

poem_df = pd.read_csv("C:\\Users\\snmuj\\Documents\\NLP--Course1\\Arabic_Poem Comprehensive_Dataset.csv")
print("Shape:", poem_df.shape)
print("Index:", poem_df.index)
poem_df.head()
# Out:
# Shape: (1831770, 9)
# Index: RangeIndex(start=0, stop=1831770, step=1)
#    Unnamed: 0        العصر             الشاعر          الديوان القافية  \
# 0           0  قبل الإسلام  عمرو بنِ قُمَيئَة  الديوان الرئيسي       د
# 1           1  قبل الإسلام  عمرو بنِ قُمَيئَة  الديوان الرئيسي       د
# 2           2  قبل الإسلام  عمرو بنِ قُمَيئَة  الديوان الرئيسي       د
# 3           3  قبل الإسلام  عمرو بنِ قُمَيئَة  الديوان الرئيسي       د
# 4           4  قبل الإسلام  عمرو بنِ قُمَيئَة  الديوان الرئيسي       د
#
#     البحر                           الشطر الايسر  \
# 0  الطويل   وَأَن تَجمَعا شَملي وَتَنتَظِرا غَدا
# 1  الطويل  وَلا سُرعَتي يَوماً بِسابِقَةِ الرَدى
# 2  الطويل  وَتَستَوجِبا مَنّاً عَلَيَّ وَتُحمَدا
# 3  الطويل    تُؤامِرُني سِرّاً لِأَصرِمَ مَرثَدا
# 4  الطويل   وَأَفرَعَ في لَومي مِراراً وَأَصعَدا
#
#                              الشطر الايمن  \
# 0   خَليلَيَّ لا تَستَعجِلا أَن تَزَوَّدا
# 1     فَما لَبَثٌ يَوماً بِسابِقٍ مَغنَمٍ
# ...

# %%
poem_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1831770 entries, 0 to 1831769
# Data columns (total 9 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   Unnamed: 0    int64
#  1   العصر         object
#  2   الشاعر        object
#  3   الديوان       object
#  4   القافية       object
#  5   البحر         object
#  6   الشطر الايسر  object
#  7   الشطر الايمن  object
#  8   البيت         object
# dtypes: int64(1), object(8)
# memory usage: 125.8+ MB

# %%
poem_df.isna().sum().sum()
# Out:
# 160074

# %%
poem_df['العصر'].isna().sum()
# Out:
# 0

# %%
poem_df['الشاعر'].isna().sum()
# Out:
# 0

# %%
poem_df['الديوان'].isna().sum()
# Out:
# 27

# %%
poem_df['القافية'].isna().sum()
# Out:
# 9760

# %%
poem_df['البحر'].isna().sum()
# Out:
# 92334

# %%
poem_df['الشطر الايسر'].isna().sum()
# Out:
# 57910

# %%
poem_df['الشطر الايمن'].isna().sum()
# Out:
# 43

# %%
poem_df['البيت'].isna().sum()
# Out:
# 0

# %%
df = poem_df.dropna()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1684668 entries, 0 to 1831769
# Data columns (total 9 columns):
#  #   Column        Non-Null Count    Dtype
# ---  ------        --------------    -----
#  0   Unnamed: 0    1684668 non-null  int64
#  1   العصر         1684668 non-null  object
#  2   الشاعر        1684668 non-null  object
#  3   الديوان       1684668 non-null  object
#  4   القافية       1684668 non-null  object
#  5   البحر         1684668 non-null  object
#  6   الشطر الايسر  1684668 non-null  object
#  7   الشطر الايمن  1684668 non-null  object
#  8   البيت         1684668 non-null  object
# dtypes: int64(1), object(8)
# memory usage: 128.5+ MB

# %%
df['العصر'].nunique()
# Out:
# 12

# %%
df['العصر'].unique()
# Out:
# array(['قبل الإسلام', 'المخضرمين', 'العباسي', 'الأموي', 'المملوكي',
#        'المغرب والأندلس', 'بين الدولتين', 'الفاطمي', 'الأيوبي', 'الحديث',
#        'الإسلامي', 'العثماني'], dtype=object)

# %%
df['الشاعر'].nunique()
# Out:
# 3366

# %%
df['الشاعر'].unique()
# Out:
# array(['عمرو بنِ قُمَيئَة', 'السُليَك بن السَلَكَة', 'عمرو بن بَرّاقَة',
#        ..., 'الربيع بن البارع الزوزني', 'ممويه الكرخي',
#        'أصبهدوست الديلمي'], dtype=object)

# %%
df['الديوان'].nunique()
# Out:
# 749

# %%
df['القافية'].nunique()
# Out:
# 35

# %%
df['القافية'].unique()
# Out:
# array(['د', 'ح', 'م', 'ل', 'ف', 'ب', 'ر', 'ي', 'ء', 'ت', 'ن', 'ج', 'ذ',
#        'ز', 'س', 'ش', 'ض', 'ع', 'ق', 'ك', 'ه', 'ط', 'ث', 'و', 'ا', 'خ',
#        'غ', 'ص', 'ظ', 'ى', 'هـ', 'هن', 'لا', 'ؤ', 'طن'], dtype=object)

# %%
df['البحر'].nunique()
# Out:
# 23

# %%
df['البحر'].unique()
# Out:
# array(['الطويل', 'المنسرح', 'المتقارب', 'الخفيف', 'الكامل', 'السريع',
#        'الوافر', 'البسيط', 'الرجز', 'الرمل', 'المجتث', 'المديد', 'الهزج',
#        'المتدارك', 'المقتضب', 'المضارع', 'شعر التفعيلة', 'الدوبيت',
#        'موشح', 'السلسلة', 'المواليا', 'شعر حر', 'عامي'], dtype=object)

# %% [markdown]
# # 2. خرج البيانات بعد استبعاد الخلايا الفارغة
#
# # Output after remvoing the balnk rows
# ***
# ### Dataset
# - **What is the dataset about ?**
#
# * عدد المداخل: 1831770
# * عدد البيانات المفقودة 160074
# * في الديوان 27
# * في القافية 9760
# * في البحر 92334
# * في الشطر الأيسر 57910
# * في الشطر الأيمن 43
#
# ### البيانات بعد فلترة الخلايا الفارغة
# * إزالة البيانات المفقودة
# * عدد الأسطر بعد الإزالة 1684668
#
# ### معلومات أولية عن بعض المتغيرات
# * عدد العصور 12
# * عدد الشعراء 3366
# * عدد الدواين 749
# * عدد القوافي 35
# * عدد البحور 23
# ### <div class="alert alert-block alert-success"> مهام المعالجة بعد تصفية الباينات المفقودة هو إجراء حساب تكرار الكلمة تكرار  المستند العكسي ثم استخراج الموضوعات وقد تزيد لاحقا </div>

# %%
df.to_csv('clean_Arabic_Poem Comprehensive_Dataset.csv', encoding="utf-8-sig")

# %% [raw]
# df.loc[df['column_name'] == some_value] #to get specific scalar from rows
# df.loc[df['column_name'].isin(some_values)] #to get specific iterable from rows
# df.loc[(df['column_name'] >= A) & (df['column_name'] <= B)] #to get specific scalar from rows
# df['column_name'] >= A & df['column_name'] <= B #conditions
# df['column_name'] >= (A & df['column_name']) <= B #conditions
# df.loc[df['column_name'] != some_value] #to get rows whose columsn value does not equal some_value
# df.loc[~df['column_name'].isin(some_values)] #isin returns boolean or iterable and to get rows whose value is not in some_values

# %% [markdown]
# # 3. تصنيف البيانات وفق بعض العصور

# %%
islamic = pd.read_csv("clean_Arabic_Poem Comprehensive_Dataset.csv")

# %%
islamic.loc[islamic['العصر'] == ('قبل الإسلام')]
# Out:
#          Unnamed: 0.1  Unnamed: 0        العصر                 الشاعر  \
# 0                   0           0  قبل الإسلام      عمرو بنِ قُمَيئَة
# 1                   1           1  قبل الإسلام      عمرو بنِ قُمَيئَة
# 2                   2           2  قبل الإسلام      عمرو بنِ قُمَيئَة
# 3                   3           3  قبل الإسلام      عمرو بنِ قُمَيئَة
# 4                   4           4  قبل الإسلام      عمرو بنِ قُمَيئَة
# ...               ...         ...          ...                    ...
# 1681060       1826323     1826323  قبل الإسلام            درهم بن زيد
# 1681061       1826324     1826324  قبل الإسلام            درهم بن زيد
# 1683929       1830596     1830596  قبل الإسلام  سعدة بنت فريد الأسدية
# 1683930       1830597     1830597  قبل الإسلام  سعدة بنت فريد الأسدية
# 1683931       1830598     1830598  قبل الإسلام  سعدة بنت فريد الأسدية
#
#                              الديوان القافية    البحر  \
# 0                    الديوان الرئيسي       د   الطويل
# ...

# %%
islamic.loc[islamic['العصر'] == ('قبل الإسلام')].to_csv('clean_islamic-poems.csv', encoding="utf-8-sig")

# %%
abbasid = pd.read_csv("clean_Arabic_Poem Comprehensive_Dataset.csv")

# %%
abbasid.loc[abbasid['العصر'] == ('العباسي')]
# Out:
#          Unnamed: 0.1  Unnamed: 0    العصر                     الشاعر  \
# 387               396         396  العباسي                المُتَنَبّي
# 388               397         397  العباسي                المُتَنَبّي
# 389               398         398  العباسي                المُتَنَبّي
# 390               399         399  العباسي                المُتَنَبّي
# 391               400         400  العباسي                المُتَنَبّي
# ...               ...         ...      ...                        ...
# 1684651       1831753     1831753  العباسي  أبو علي الدامغاني القومسي
# 1684652       1831754     1831754  العباسي  أبو علي الدامغاني القومسي
# 1684653       1831755     1831755  العباسي  أبو علي الدامغاني القومسي
# 1684654       1831756     1831756  العباسي  أبو علي الدامغاني القومسي
# 1684655       1831757     1831757  العباسي  أبو علي الدامغاني القومسي
#
#                            الديوان القافية   البحر  \
# 387                الديوان الرئيسي       ء  الكامل
# ...

# %%
abbasid.loc[abbasid['العصر'] == ('العباسي')].to_csv('clean_abbasid-poems.csv', encoding="utf-8-sig")

# %%
andalus = pd.read_csv("clean_Arabic_Poem Comprehensive_Dataset.csv")

# %%
andalus.loc[andalus['العصر'] == ('المغرب والأندلس')]
# Out:
#          Unnamed: 0.1  Unnamed: 0            العصر  \
# 74511           74928       74928  المغرب والأندلس
# 74512           74929       74929  المغرب والأندلس
# 74513           74930       74930  المغرب والأندلس
# 74514           74931       74931  المغرب والأندلس
# 74515           74932       74932  المغرب والأندلس
# ...               ...         ...              ...
# 1684531       1831633     1831633  المغرب والأندلس
# 1684532       1831634     1831634  المغرب والأندلس
# 1684533       1831635     1831635  المغرب والأندلس
# 1684534       1831636     1831636  المغرب والأندلس
# 1684535       1831637     1831637  المغرب والأندلس
#
#                               الشاعر                      الديوان القافية  \
# 74511             أبو اسحاق الألبيري              الديوان الرئيسي       ت
# 74512             أبو اسحاق الألبيري              الديوان الرئيسي       ت
# 74513             أبو اسحاق الألبيري              الديوان الرئيسي       ت
# ...

# %%
andalus.loc[andalus['العصر'] == ('المغرب والأندلس')].to_csv('clean_andalus-poems.csv', encoding="utf-8-sig")

# %%
otman = pd.read_csv("clean_Arabic_Poem Comprehensive_Dataset.csv")

# %%
otman.loc[otman['العصر'] == ('العثماني')]
# Out:
#          Unnamed: 0.1  Unnamed: 0     العصر             الشاعر  \
# 374618         383525      383525  العثماني         بنت الشحنة
# 374619         383526      383526  العثماني         بنت الشحنة
# 374620         383527      383527  العثماني         بنت الشحنة
# 374621         383528      383528  العثماني         بنت الشحنة
# 374622         383529      383529  العثماني         بنت الشحنة
# ...               ...         ...       ...                ...
# 1684389       1831491     1831491  العثماني  عبد الكريم الفكون
# 1684390       1831492     1831492  العثماني  عبد الكريم الفكون
# 1684391       1831493     1831493  العثماني  عبد الكريم الفكون
# 1684392       1831494     1831494  العثماني  عبد الكريم الفكون
# 1684393       1831495     1831495  العثماني  عبد الكريم الفكون
#
#                    الديوان القافية   البحر                    الشطر الايسر  \
# 374618     الديوان الرئيسي       ن  البسيط       وجلت فينا بجد ليسٍ بالحسن
# ...

# %%
otman.loc[otman['العصر'] == ('العثماني')].to_csv('clean_otman-poems.csv', encoding="utf-8-sig")

# %%
modern = pd.read_csv("clean_Arabic_Poem Comprehensive_Dataset.csv")

# %%
modern.loc[modern['العصر'] == ('الحديث')]
# Out:
#          Unnamed: 0.1  Unnamed: 0   العصر     الشاعر          الديوان القافية  \
# 195118         198186      198186  الحديث  أحمد شوقي  الديوان الرئيسي       ء
# 195119         198187      198187  الحديث  أحمد شوقي  الديوان الرئيسي       ء
# 195120         198188      198188  الحديث  أحمد شوقي  الديوان الرئيسي       ء
# 195121         198189      198189  الحديث  أحمد شوقي  الديوان الرئيسي       ء
# 195122         198190      198190  الحديث  أحمد شوقي  الديوان الرئيسي       ء
# ...               ...         ...     ...        ...              ...     ...
# 1684663       1831765     1831765  الحديث  شهاب غانم        شهاب غانم       ن
# 1684664       1831766     1831766  الحديث  شهاب غانم        شهاب غانم       ن
# 1684665       1831767     1831767  الحديث  شهاب غانم        شهاب غانم       ن
# 1684666       1831768     1831768  الحديث  شهاب غانم        شهاب غانم       ن
# 1684667       1831769     1831769  الحديث  شهاب غانم        شهاب غانم       ن
#
# ...

# %%
modern.loc[modern['العصر'] == ('الحديث')].to_csv('clean_modern-poems.csv', encoding="utf-8-sig")

# %% [markdown]
# # 4. إزالة كلمات الإيقاف
#
# # عدد الكلمات لكل بيت
#
# # TF-IDF and BoW
#
# # عدد البحور مقابل العصور، وعدد القوافي مقابل العصور، وعدد الكلمات لكل بيت بناء على العصور، إلخ

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import re
import pickle 
import time
import nltk
from nltk import Text
from nltk.tokenize import regexp_tokenize
from nltk.tokenize import word_tokenize  
from nltk.tokenize import sent_tokenize 
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.stem import PorterStemmer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression 
from sklearn.naive_bayes import MultinomialNB
from sklearn.multiclass import OneVsRestClassifier
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import make_pipeline
import pandas as pd
import numpy as np
df = pd.read_csv('clean_Arabic_Poem Comprehensive_Dataset.csv', encoding="utf-8-sig")

# %%
df['word_count'] = df['البيت'].apply(lambda x: len(str(x).split(" ")))
df[['البيت','word_count']].head()
# Out:
#                                                البيت  word_count
# 0  خَليلَيَّ لا تَستَعجِلا أَن تَزَوَّدا    وَأَن...          13
# 1  فَما لَبَثٌ يَوماً بِسابِقٍ مَغنَمٍ    وَلا سُ...          13
# 2  وَإِن تُنظِراني اليَومَ أَقضِ لُبانَةً    وَتَ...          12
# 3  لَعَمرُكَ ما نَفسٌ بِجِدٍ رَشيدَةٍ    تُؤامِرُ...          12
# 4  وَإِن ظَهَرَت مِنهُ قَوارِصُ جَمَّةٌ    وَأَفر...          13

# %%
def avg_word(sentence):
  words = sentence.split()
  return (sum(len(word) for word in words)/len(words))

df['avg_word'] = df['البيت'].apply(lambda x: avg_word(x))
df[['البيت','avg_word']].head()
# Out:
#                                                البيت  avg_word
# 0  خَليلَيَّ لا تَستَعجِلا أَن تَزَوَّدا    وَأَن...  6.500000
# 1  فَما لَبَثٌ يَوماً بِسابِقٍ مَغنَمٍ    وَلا سُ...  6.400000
# 2  وَإِن تُنظِراني اليَومَ أَقضِ لُبانَةً    وَتَ...  7.555556
# 3  لَعَمرُكَ ما نَفسٌ بِجِدٍ رَشيدَةٍ    تُؤامِرُ...  6.888889
# 4  وَإِن ظَهَرَت مِنهُ قَوارِصُ جَمَّةٌ    وَأَفر...  6.400000

# %%
from nltk.corpus import stopwords
stop = stopwords.words('function-ar')

df['stopwords'] = df['البيت'].apply(lambda x: len([x for x in x.split() if x in stop]))
df[['البيت','stopwords']].head()
# Out:
#                                                البيت  stopwords
# 0  خَليلَيَّ لا تَستَعجِلا أَن تَزَوَّدا    وَأَن...          1
# 1  فَما لَبَثٌ يَوماً بِسابِقٍ مَغنَمٍ    وَلا سُ...          0
# 2  وَإِن تُنظِراني اليَومَ أَقضِ لُبانَةً    وَتَ...          0
# 3  لَعَمرُكَ ما نَفسٌ بِجِدٍ رَشيدَةٍ    تُؤامِرُ...          1
# 4  وَإِن ظَهَرَت مِنهُ قَوارِصُ جَمَّةٌ    وَأَفر...          1

# %%
df['punctuations'] = df['البيت'].apply(lambda x: len([x for x in x.split() if x.startswith('.,:')]))
df[['البيت','punctuations']].head()
# Out:
#                                                البيت  punctuations
# 0  خَليلَيَّ لا تَستَعجِلا أَن تَزَوَّدا    وَأَن...             0
# 1  فَما لَبَثٌ يَوماً بِسابِقٍ مَغنَمٍ    وَلا سُ...             0
# 2  وَإِن تُنظِراني اليَومَ أَقضِ لُبانَةً    وَتَ...             0
# 3  لَعَمرُكَ ما نَفسٌ بِجِدٍ رَشيدَةٍ    تُؤامِرُ...             0
# 4  وَإِن ظَهَرَت مِنهُ قَوارِصُ جَمَّةٌ    وَأَفر...             0

# %%
#df['البيت'] = df['البيت'].str.replace('.,:','')
#df['البيت'].head()

# %%
freq = pd.Series(' '.join(df['البيت']).split()).value_counts()[:10]
print(freq)
# Out:
# في     339840
# من     257867
# ما     170658
# لا     109296
# يا      91602
# مِن     89260
# على     87234
# قد      57562
# عن      49478
# ولا     48257
# dtype: int64

# %%
freq = list(freq.index)
df['البيت'] = df['البيت'].apply(lambda x: " ".join(x for x in x.split() if x not in freq))
df['البيت'].head()
# Out:
# 0    خَليلَيَّ تَستَعجِلا أَن تَزَوَّدا وَأَن تَجمَ...
# 1    فَما لَبَثٌ يَوماً بِسابِقٍ مَغنَمٍ وَلا سُرعَ...
# 2    وَإِن تُنظِراني اليَومَ أَقضِ لُبانَةً وَتَستَ...
# 3    لَعَمرُكَ نَفسٌ بِجِدٍ رَشيدَةٍ تُؤامِرُني سِر...
# 4    وَإِن ظَهَرَت مِنهُ قَوارِصُ جَمَّةٌ وَأَفرَعَ...
# Name: البيت, dtype: object

# %%
freq = pd.Series(' '.join(df['البيت']).split()).value_counts()[-10:]
freq
# Out:
# الأثمنُ    1
# أحزنُ      1
# يمخرُ      1
# ترميكمُ    1
# فاجأتكم    1
# تلهيكمُ    1
# تغويكمُ    1
# تشديدكم    1
# إحجامكم    1
# لجنا       1
# dtype: int64

# %%
#from textblob_ar import TextBlob
#blob = TextBlob(df['البيت'][1]).words
#blob.tokens

from textblob import TextBlob
TextBlob(df['البيت'][1]).words
# Out:
# WordList(['فَما', 'لَبَثٌ', 'يَوماً', 'بِسابِقٍ', 'مَغنَمٍ', 'وَلا', 'سُرعَتي', 'يَوماً', 'بِسابِقَةِ', 'الرَدى'])

# %%
TextBlob(df['البيت'][1]).words
# Out:
# WordList(['فَما', 'لَبَثٌ', 'يَوماً', 'بِسابِقٍ', 'مَغنَمٍ', 'وَلا', 'سُرعَتي', 'يَوماً', 'بِسابِقَةِ', 'الرَدى'])

# %%
from nltk.stem import PorterStemmer
st = PorterStemmer()
df['البيت'][:5].apply(lambda x: " ".join([st.stem(word) for word in x.split()]))
# Out:
# 0    خَليلَيَّ تَستَعجِلا أَن تَزَوَّدا وَأَن تَجمَ...
# 1    فَما لَبَثٌ يَوماً بِسابِقٍ مَغنَمٍ وَلا سُرعَ...
# 2    وَإِن تُنظِراني اليَومَ أَقضِ لُبانَةً وَتَستَ...
# 3    لَعَمرُكَ نَفسٌ بِجِدٍ رَشيدَةٍ تُؤامِرُني سِر...
# 4    وَإِن ظَهَرَت مِنهُ قَوارِصُ جَمَّةٌ وَأَفرَعَ...
# Name: البيت, dtype: object

# %%
from textblob import Word
df['البيت'] = df['البيت'].apply(lambda x: " ".join([Word(word).lemmatize() for word in x.split()]))
df['البيت'].head()
# Out:
# 0    خَليلَيَّ تَستَعجِلا أَن تَزَوَّدا وَأَن تَجمَ...
# 1    فَما لَبَثٌ يَوماً بِسابِقٍ مَغنَمٍ وَلا سُرعَ...
# 2    وَإِن تُنظِراني اليَومَ أَقضِ لُبانَةً وَتَستَ...
# 3    لَعَمرُكَ نَفسٌ بِجِدٍ رَشيدَةٍ تُؤامِرُني سِر...
# 4    وَإِن ظَهَرَت مِنهُ قَوارِصُ جَمَّةٌ وَأَفرَعَ...
# Name: البيت, dtype: object

# %%
TextBlob(df['البيت'][0]).ngrams(2)
# Out:
# [WordList(['خَليلَيَّ', 'تَستَعجِلا']),
#  WordList(['تَستَعجِلا', 'أَن']),
#  WordList(['أَن', 'تَزَوَّدا']),
#  WordList(['تَزَوَّدا', 'وَأَن']),
#  WordList(['وَأَن', 'تَجمَعا']),
#  WordList(['تَجمَعا', 'شَملي']),
#  WordList(['شَملي', 'وَتَنتَظِرا']),
#  WordList(['وَتَنتَظِرا', 'غَدا'])]

# %%
tf = (df['البيت'][1:2]).apply(lambda x: pd.value_counts(x.split(" "))).sum(axis = 0).reset_index()
tf.columns = ['words','tf']
tf
# Out:
#         words  tf
# 0      يَوماً   2
# 1        فَما   1
# 2      لَبَثٌ   1
# 3    بِسابِقٍ   1
# 4     مَغنَمٍ   1
# 5        وَلا   1
# 6     سُرعَتي   1
# 7  بِسابِقَةِ   1
# 8      الرَدى   1

# %%
for i,word in enumerate(tf['words']):
  tf.loc[i, 'idf'] = np.log(df.shape[0]/(len(df[df['البيت'].str.contains(word)])))
tf
# Out:
#         words  tf        idf
# 0      يَوماً   2   6.118831
# 1        فَما   1   5.160295
# 2      لَبَثٌ   1  13.238467
# 3    بِسابِقٍ   1  12.950785
# 4     مَغنَمٍ   1  11.852172
# 5        وَلا   1   4.098763
# 6     سُرعَتي   1  13.238467
# 7  بِسابِقَةِ   1  13.238467
# 8      الرَدى   1   7.121839

# %%
tf['tfidf'] = tf['tf'] * tf['idf']
tf
# Out:
#         words  tf        idf      tfidf
# 0      يَوماً   2   6.118831  12.237662
# 1        فَما   1   5.160295   5.160295
# 2      لَبَثٌ   1  13.238467  13.238467
# 3    بِسابِقٍ   1  12.950785  12.950785
# 4     مَغنَمٍ   1  11.852172  11.852172
# 5        وَلا   1   4.098763   4.098763
# 6     سُرعَتي   1  13.238467  13.238467
# 7  بِسابِقَةِ   1  13.238467  13.238467
# 8      الرَدى   1   7.121839   7.121839

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf = TfidfVectorizer(max_features=1000, lowercase=True, analyzer='word',
                        stop_words= 'english',ngram_range=(1,1))
train_vect = tfidf.fit_transform(df['البيت'])
train_vect
# Out:
# <1684668x1000 sparse matrix of type '<class 'numpy.float64'>'
# 	with 7117151 stored elements in Compressed Sparse Row format>

# %%
from sklearn.feature_extraction.text import CountVectorizer
bow = CountVectorizer(max_features=1000, lowercase=True, ngram_range=(1,1),analyzer = "word")
train_bow = bow.fit_transform(df['البيت'])
train_bow
# Out:
# <1684668x1000 sparse matrix of type '<class 'numpy.int64'>'
# 	with 7186121 stored elements in Compressed Sparse Row format>

# %% [raw]
# from gensim.scripts.glove2word2vec import glove2word2vec
# glove_input_file = "C:\\Users\\snmuj\\Downloads\\glove.6B.100d.txt\\glove.6B.100d.txt"
# word2vec_output_file = 'glove.6B.100d.txt.word2vec'
# glove2word2vec(glove_input_file, word2vec_output_file)

# %% [raw]
# from gensim.models import KeyedVectors # load the Stanford GloVe model
# filename = 'glove.6B.100d.txt.word2vec'
# model = KeyedVectors.load_word2vec_format(filename, binary=False)

# %% [raw]
# model['مَغنَمٍ']

# %%
df[['البيت','word_count']].head()
# Out:
#                                                البيت  word_count
# 0  خَليلَيَّ تَستَعجِلا أَن تَزَوَّدا وَأَن تَجمَ...          13
# 1  فَما لَبَثٌ يَوماً بِسابِقٍ مَغنَمٍ وَلا سُرعَ...          13
# 2  وَإِن تُنظِراني اليَومَ أَقضِ لُبانَةً وَتَستَ...          12
# 3  لَعَمرُكَ نَفسٌ بِجِدٍ رَشيدَةٍ تُؤامِرُني سِر...          12
# 4  وَإِن ظَهَرَت مِنهُ قَوارِصُ جَمَّةٌ وَأَفرَعَ...          13

# %%
#df['العصر'].unique()
#df['القافية'].unique()
df['البحر'].unique()
# Out:
# array(['الطويل', 'المنسرح', 'المتقارب', 'الخفيف', 'الكامل', 'السريع',
#        'الوافر', 'البسيط', 'الرجز', 'الرمل', 'المجتث', 'المديد', 'الهزج',
#        'المتدارك', 'المقتضب', 'المضارع', 'شعر التفعيلة', 'الدوبيت',
#        'موشح', 'السلسلة', 'المواليا', 'شعر حر', 'عامي'], dtype=object)

# %%
# count values in name column
print(df['العصر'].value_counts()['قبل الإسلام'])
print(df['العصر'].value_counts()['المخضرمين'])
print(df['العصر'].value_counts()['العباسي'])
print(df['العصر'].value_counts()['الأموي'])
print(df['العصر'].value_counts()['المملوكي'])
print(df['العصر'].value_counts()['المغرب والأندلس'])
print(df['العصر'].value_counts()['بين الدولتين'])
print(df['العصر'].value_counts()['الفاطمي'])
print(df['العصر'].value_counts()['الأيوبي'])
print(df['العصر'].value_counts()['الحديث'])
print(df['العصر'].value_counts()['الإسلامي'])
print(df['العصر'].value_counts()['العثماني'])
print ('__________________________________________________')
print(df['البحر'].value_counts()['الطويل'])
print(df['البحر'].value_counts()['المنسرح'])
print(df['البحر'].value_counts()['المتقارب'])
print(df['البحر'].value_counts()['الخفيف'])
print(df['البحر'].value_counts()['الكامل'])
print(df['البحر'].value_counts()['السريع'])
print(df['البحر'].value_counts()['الوافر'])
print(df['البحر'].value_counts()['البسيط'])
print(df['البحر'].value_counts()['الرجز'])
print(df['البحر'].value_counts()['الرمل'])
print(df['البحر'].value_counts()['المجتث'])
print(df['البحر'].value_counts()['المديد'])
print(df['البحر'].value_counts()['الهزج'])
print(df['البحر'].value_counts()['المتدارك'])
print(df['البحر'].value_counts()['المقتضب'])
print(df['البحر'].value_counts()['المضارع'])
print(df['البحر'].value_counts()['شعر التفعيلة'])
print(df['البحر'].value_counts()['الدوبيت'])
print(df['البحر'].value_counts()['موشح'])
print(df['البحر'].value_counts()['السلسلة'])
print(df['البحر'].value_counts()['المواليا'])
print(df['البحر'].value_counts()['شعر حر'])
print(df['البحر'].value_counts()['المواليا'])
print(df['البحر'].value_counts()['عامي'])
# Out:
# 21324
# 29891
# 231513
# 61917
# 158138
# 107088
# 18351
# 122789
# 110687
# 669688
# 2136
# 151146
# __________________________________________________
# 398215
# 28052
# 62463
# 152561
# 358813
# 57081
# 139310
# 236636
# 103101
# 73261
# 17591
# 7650
# 7306
# 4507
# 795
# 288
# 164
# 2710
# 25356
# 724
# 1251
# 32
# 1251
# 6801

# %%
# count values in name column
print(df['العصر'].value_counts(['قبل الإسلام'], ['العثماني']))

print ('__________________________________________________')

print(df['القافية'].value_counts(['د'], ['طن']))

print ('__________________________________________________')

print(df['البحر'].value_counts(['الطويل'], ['عامي']))
# Out:
# الحديث             0.397519
# العباسي            0.137424
# المملوكي           0.093869
# العثماني           0.089719
# الفاطمي            0.072886
# الأيوبي            0.065703
# المغرب والأندلس    0.063566
# الأموي             0.036753
# المخضرمين          0.017743
# قبل الإسلام        0.012658
# بين الدولتين       0.010893
# الإسلامي           0.001268
# Name: العصر, dtype: float64
# __________________________________________________
# ر     0.156803
# ل     0.117252
# م     0.113198
# د     0.111903
# ب     0.098296
# ن     0.094375
# ع     0.039814
# ق     0.039118
# ء     0.028954
# ت     0.027820
# ف     0.025489
# ح     0.024560
# ه     0.022140
# س     0.020685
# ي     0.017796
# ك     0.015719
# ج     0.009250
# ض     0.007234
# ا     0.004886
# ط     0.004620
# ز     0.003130
# ش     0.002928
# ص     0.002897
# و     0.002748
# ث     0.002374
# ذ     0.001622
# خ     0.001359
# غ     0.001234
# ظ     0.000959
# ى     0.000756
# هـ    0.000066
# ؤ     0.000005
# ...

# %%
# count all values in name column in ascending order
print(df['العصر'].value_counts(ascending=False))
# Out:
# الحديث             669688
# العباسي            231513
# المملوكي           158138
# العثماني           151146
# الفاطمي            122789
# الأيوبي            110687
# المغرب والأندلس    107088
# الأموي              61917
# المخضرمين           29891
# قبل الإسلام         21324
# بين الدولتين        18351
# الإسلامي             2136
# Name: العصر, dtype: int64

# %% [raw]
# #groupby() function
# df.groupby(['العصر', 'البحر', 'القافية'])
# print(df.groupby(['العصر', 'البحر', 'القافية']).groups)

# %%
df.groupby('العصر')['البحر'].value_counts().unstack().fillna(0)
# Out:
# البحر             البسيط   الخفيف  الدوبيت    الرجز    الرمل   السريع  \
# العصر
# الأموي            7882.0   2806.0      0.0    691.0    835.0    587.0
# الأيوبي          17003.0   6329.0    342.0   5900.0   4156.0   5492.0
# الإسلامي           204.0     56.0      0.0     63.0    119.0      2.0
# الحديث           96423.0  76977.0    179.0  41401.0  40640.0  16969.0
# العباسي          26906.0  23482.0      6.0  17376.0   8050.0  11886.0
# العثماني         23287.0  15092.0    369.0   8122.0   7170.0   4445.0
# الفاطمي          16666.0   9152.0     92.0   8299.0   2258.0   5852.0
# المخضرمين         3777.0    939.0      0.0    344.0    562.0    571.0
# المغرب والأندلس  14478.0   4338.0     60.0   2119.0   3683.0   3828.0
# المملوكي         25478.0  11061.0   1662.0  14960.0   4375.0   5984.0
# بين الدولتين      2026.0   1397.0      0.0   3509.0    673.0    883.0
# قبل الإسلام       2506.0    932.0      0.0    317.0    740.0    582.0
#
# ...

# %%
df.groupby('العصر')['القافية'].value_counts().unstack()
# Out:
# القافية                ء    ؤ       ا        ب        ت      ث       ج  \
# العصر
# الأموي             849.0  NaN   149.0   7615.0    909.0   95.0   601.0
# الأيوبي           3016.0  NaN   284.0  10396.0   3489.0  276.0   741.0
# الإسلامي            22.0  NaN     4.0    314.0     42.0    NaN    30.0
# الحديث           24746.0  NaN  2920.0  62577.0  23349.0  948.0  4429.0
# العباسي           4423.0  NaN  1431.0  25709.0   4565.0  745.0  2207.0
# العثماني          4952.0  NaN   855.0  12697.0   3748.0  455.0  1923.0
# الفاطمي           3260.0  8.0   604.0  12043.0   2636.0  393.0  1654.0
# المخضرمين          336.0  NaN   111.0   3256.0    377.0   45.0   250.0
# المغرب والأندلس   3277.0  NaN   514.0  10513.0   1757.0  470.0  1395.0
# المملوكي          3120.0  NaN  1224.0  14586.0   4978.0  442.0  1885.0
# بين الدولتين       467.0  NaN    48.0   3361.0    591.0  117.0   284.0
# قبل الإسلام        310.0  NaN    88.0   2529.0    426.0   14.0   185.0
#
# ...

# %%
df.groupby('القافية')['البحر'].value_counts().unstack()
# Out:
# البحر     البسيط   الخفيف  الدوبيت    الرجز   الرمل  السريع  السلسلة   الطويل  \
# القافية
# ء         3691.0  13540.0    118.0   1686.0  1967.0   417.0      NaN   3435.0
# ؤ            NaN      8.0      NaN      NaN     NaN     NaN      NaN      NaN
# ا          264.0    562.0     10.0   2376.0   486.0   281.0      NaN   1234.0
# ب        24942.0  10993.0    185.0   9070.0  6712.0  5404.0     30.0  47950.0
# ت         6814.0   4450.0     78.0   1947.0  2175.0  1450.0      NaN  14516.0
# ث          474.0    250.0     32.0     87.0    63.0   108.0      NaN   1635.0
# ج         2853.0    706.0     30.0    906.0   691.0   532.0      NaN   3092.0
# ح         4137.0   3340.0    100.0   1743.0  2640.0  2463.0     23.0   9272.0
# خ          134.0    211.0     18.0     58.0    26.0   158.0      NaN    975.0
# د        20833.0  16208.0    198.0  14566.0  7329.0  5189.0     77.0  49869.0
# ذ          207.0    182.0     24.0    292.0   151.0    82.0      NaN    481.0
# ...

# %%
df['word_count'] = df['البيت'].apply(lambda x: len(str(x).split(" ")))
df[['البيت','word_count']].head()
# Out:
#                                                البيت  word_count
# 0  خَليلَيَّ تَستَعجِلا أَن تَزَوَّدا وَأَن تَجمَ...           9
# 1  فَما لَبَثٌ يَوماً بِسابِقٍ مَغنَمٍ وَلا سُرعَ...          10
# 2  وَإِن تُنظِراني اليَومَ أَقضِ لُبانَةً وَتَستَ...           9
# 3  لَعَمرُكَ نَفسٌ بِجِدٍ رَشيدَةٍ تُؤامِرُني سِر...           8
# 4  وَإِن ظَهَرَت مِنهُ قَوارِصُ جَمَّةٌ وَأَفرَعَ...           9

# %%
df.groupby('العصر')['word_count'].value_counts().unstack()
# Out:
# word_count         2      3       4        5        6        7         8   \
# العصر
# الأموي            NaN    NaN    48.0    189.0   1116.0   3760.0   12834.0
# الأيوبي          16.0   31.0   614.0   1861.0   6425.0  12082.0   26841.0
# الإسلامي          NaN    NaN     2.0      4.0     37.0    166.0     531.0
# الحديث           38.0  110.0  4100.0  12330.0  42998.0  77712.0  175963.0
# العباسي           1.0    5.0   987.0   3753.0  16958.0  32321.0   60683.0
# العثماني          8.0   25.0   988.0   3124.0   9972.0  16585.0   36512.0
# الفاطمي           NaN    9.0   589.0   1370.0   6835.0  13652.0   31117.0
# المخضرمين         NaN    NaN    10.0     72.0    619.0   2369.0    7007.0
# المغرب والأندلس   3.0   70.0   985.0   2466.0   6445.0  10350.0   24628.0
# المملوكي          5.0   68.0  1023.0   2674.0   8819.0  16159.0   38498.0
# بين الدولتين      NaN    NaN    40.0    234.0    831.0   1943.0    4815.0
# قبل الإسلام       NaN    NaN     5.0     74.0    522.0   1856.0    5566.0
# ...

# %%
df.groupby('البحر')['word_count'].value_counts().unstack()
# Out:
# word_count      2      3       4       5        6        7         8   \
# البحر
# البسيط         1.0   12.0   158.0   295.0   3342.0   8893.0   36052.0
# الخفيف         NaN    7.0   448.0  1395.0   5432.0  20541.0   50717.0
# الدوبيت        NaN    NaN     2.0     7.0     99.0    220.0     682.0
# الرجز         13.0   20.0  2689.0  5693.0  14453.0  21017.0   30480.0
# الرمل          3.0   11.0   934.0  3938.0  11513.0  14224.0   23114.0
# السريع         2.0    NaN    75.0   233.0   5324.0  15543.0   20548.0
# السلسلة        NaN    NaN     NaN     8.0      5.0      7.0     115.0
# الطويل         NaN    NaN    38.0    64.0    413.0   4476.0   50424.0
# الكامل         4.0   24.0   479.0  4525.0  23952.0  46538.0  112033.0
# المتدارك       NaN    9.0   225.0   169.0   1315.0   1559.0     986.0
# المتقارب       NaN    3.0   116.0   242.0   5151.0  14865.0   24827.0
# المجتث        15.0   10.0   843.0  4078.0   9201.0   2897.0     457.0
# ...
